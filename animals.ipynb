# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense , Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
X_train = np.loadtxt('input.csv', delimiter=',')
Y_train = np.loadtxt('labels.csv', delimiter=',')

X_test = np.loadtxt('input_test.csv', delimiter=',')
Y_test = np.loadtxt('labels_test.csv', delimiter=',')

# %%
X_train = X_train.reshape(len(X_train),100,100,3)
Y_train = Y_train.reshape(len(Y_train),1)

X_test = X_test.reshape(len(X_test),100,100,3)
Y_test = Y_test.reshape(len(Y_test),1)

X_train = X_train / 255.0
X_test = X_test / 255.0

#data augmentation to improve training
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

# %%
print("shape of X_train:", X_train.shape)
print("shape of Y_train:", Y_train.shape)
print("shape of X_test:", X_test.shape) 
print("shape of Y_test:", Y_test.shape)
# Out:
# shape of X_train: (2000, 100, 100, 3)
# shape of Y_train: (2000, 1)
# shape of X_test: (400, 100, 100, 3)
# shape of Y_test: (400, 1)

# %%
idx = random.randint(0, len(X_train))
plt.imshow(X_train[idx, :])
plt.show()

# %%
model=Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(100,100,3)),
    MaxPooling2D((2,2)),

    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dense(64,activation='relu'),
    Dense(1,activation='sigmoid')
])
# Out:
# C:\Users\kotha\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation= 'relu', input_shape = (100,100,3))) # 32,64 is the filter
model.add(MaxPooling2D((2,2)))# converting 2d data to 1d data
model.add(Dropout(0.25)) # to remove particular data from the dataset

model.add(Conv2D(64, (3,3), activation= 'relu'))#(3,3) is the size of the filter( hidden layers)
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(datagen.flow(X_train, Y_train, batch_size=32),
          epochs=30,
          validation_data=(X_test, Y_test),
          verbose=1)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.4960 - loss: 0.7347 - val_accuracy: 0.5025 - val_loss: 0.6893
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.5080 - loss: 0.6910 - val_accuracy: 0.5100 - val_loss: 0.6923
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.5130 - loss: 0.6882 - val_accuracy: 0.5875 - val_loss: 0.6685
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.5325 - loss: 0.6846 - val_accuracy: 0.5300 - val_loss: 0.6804
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.5570 - loss: 0.6865 - val_accuracy: 0.5925 - val_loss: 0.6788
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.5485 - loss: 0.6827 - val_accuracy: 0.5550 - val_loss: 0.6858
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.5520 - loss: 0.6854 - val_accuracy: 0.5825 - val_loss: 0.6846
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.5545 - loss: 0.6808 - val_accuracy: 0.5650 - val_loss: 0.6832
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.5730 - loss: 0.6824 - val_accuracy: 0.6175 - val_loss: 0.6690
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.5630 - loss: 0.6806 - val_accuracy: 0.6025 - val_loss: 0.6707
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.5710 - loss: 0.6788 - val_accuracy: 0.6200 - val_loss: 0.6704
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.5640 - loss: 0.6800 - val_accuracy: 0.5950 - val_loss: 0.6685
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.5780 - loss: 0.6778 - val_accuracy: 0.5500 - val_loss: 0.6840
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.5750 - loss: 0.6806 - val_accuracy: 0.5925 - val_loss: 0.6764
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 128ms/step - accuracy: 0.5680 - loss: 0.6786 - val_accuracy: 0.6200 - val_loss: 0.6632
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.5660 - loss: 0.6804 - val_accuracy: 0.5875 - val_loss: 0.6765
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.5945 - loss: 0.6652 - val_accuracy: 0.6325 - val_loss: 0.6494
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.5770 - loss: 0.6795 - val_accuracy: 0.5975 - val_loss: 0.6655
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.5725 - loss: 0.6793 - val_accuracy: 0.6000 - val_loss: 0.6703
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.5725 - loss: 0.6785 - val_accuracy: 0.6275 - val_loss: 0.6634
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.5810 - loss: 0.6750 - val_accuracy: 0.6225 - val_loss: 0.6608
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.5895 - loss: 0.6705 - val_accuracy: 0.6050 - val_loss: 0.6646
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.5995 - loss: 0.6688 - val_accuracy: 0.6350 - val_loss: 0.6489
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.6105 - loss: 0.6626 - val_accuracy: 0.5950 - val_loss: 0.6636
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.5920 - loss: 0.6686 - val_accuracy: 0.6900 - val_loss: 0.6305
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.6210 - loss: 0.6508 - val_accuracy: 0.6775 - val_loss: 0.6233
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.6260 - loss: 0.6515 - val_accuracy: 0.7025 - val_loss: 0.6069
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.6415 - loss: 0.6368 - val_accuracy: 0.6700 - val_loss: 0.6240
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.6475 - loss: 0.6362 - val_accuracy: 0.7125 - val_loss: 0.5956
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.6485 - loss: 0.6349 - val_accuracy: 0.6975 - val_loss: 0.5898

# %%
model.evaluate(X_test, Y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6975 - loss: 0.5898
# [0.5897947549819946, 0.6974999904632568]

# %%
idx2= random.randint(0, len(Y_test))
plt.imshow(X_test[idx2, :])
plt.show()

y_pred = model.predict(X_test[idx2, :].reshape(1,100,100,3))
y_pred = y_pred > 0.5

if(y_pred == 0):
    pred = "dog"

else: 
    pred = 'cat'

print("The model prediction is", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# The model prediction is dog

# %%
model.save('model.h5')
print('our model is saved')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# our model is saved
